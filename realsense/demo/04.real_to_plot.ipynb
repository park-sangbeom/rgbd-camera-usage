# %%
import sys 
sys.path.append("..")
import matplotlib.pyplot as plt 
from utils.utils_pcl import *
from utils.utils_pointcloud import *
import cv2 
import rospy 
from get_rostopic import RealsenseD435i

from roslib import message
print("Done.")
# Out:
# Done.

# %% [markdown]
# ### Setup

# %%
rospy.init_node('Realsense')
mode     = "pointcloud"
camera   = RealsenseD435i(mode=mode)
name = "1025"
# print(camera.point_cloud)
np_point = ros_to_numpy(camera.point_cloud)
# Out:
# shutdown request: [/Realsense] Reason: new node registered with same name

# %%
print("Shape: {}".format(np_point.shape))
# Out:
# Shape: (106231, 3)

# %% [markdown]
# ### Plot: Real-World

# %%
save_pc(camera.point_cloud, name="test")
# Out:
# Max Depth: 10.938000679016113
# Min Depth: -1.780311107635498
# Average Depth: 0.8464749166719826
# SAVED POINTCLOUD
