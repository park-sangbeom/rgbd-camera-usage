# %%
import pyzed.sl as sl

# Create a ZED camera object
zed = sl.Camera()

# Set configuration parameters
init_params = sl.InitParameters()
init_params.camera_resolution = sl.RESOLUTION.HD720  # Use HD720 video mode (default fps: 60)
init_params.coordinate_system = sl.COORDINATE_SYSTEM.RIGHT_HANDED_Y_UP # Use a right-handed Y-up coordinate system
init_params.coordinate_units = sl.UNIT.METER  # Set units in meters

# Open the camera
err = zed.open(init_params)
if err != sl.ERROR_CODE.SUCCESS:
    exit(1)

tracking_parameters = sl.PositionalTrackingParameters()
err = zed.enable_positional_tracking(tracking_parameters)
if err != sl.ERROR_CODE.SUCCESS:
    exit(1)

mapping_parameters = sl.SpatialMappingParameters()
err = zed.enable_spatial_mapping(mapping_parameters)
if err != sl.ERROR_CODE.SUCCESS:
    exit(1)

# %%
# Grab data during 3000 frames
i = 0
py_mesh = sl.Mesh()  # Create a Mesh object
runtime_parameters = sl.RuntimeParameters()
while i < 3000:
    if zed.grab(runtime_parameters) == sl.ERROR_CODE.SUCCESS:
        # In background, spatial mapping will use new images, depth and pose to create and update the mesh. No specific functions are required here.
        mapping_state = zed.get_spatial_mapping_state()
        # Print spatial mapping state
        print("\rImages captured: {0} / 3000 || {1}".format(i, mapping_state))
        i = i + 1
# Out:
# Images captured: 0 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 1 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 3 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 4 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 5 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 6 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 7 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 8 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 9 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 10 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 11 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 12 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 13 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 14 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 15 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 16 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 17 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 18 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 19 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 20 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 21 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 22 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 23 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 24 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 25 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 26 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 27 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 28 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 29 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 30 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 31 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 32 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 33 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 34 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 35 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 36 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 37 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 38 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 39 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 40 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 41 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 42 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 43 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 44 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 45 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 46 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 47 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 48 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 49 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 50 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 51 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 52 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 53 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 54 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 55 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 56 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 57 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 58 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 59 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 60 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 61 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 62 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 63 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 64 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 65 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 66 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 67 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 68 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 69 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 70 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 71 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 72 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 73 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 74 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 75 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 76 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 77 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 78 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 79 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 80 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 81 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 82 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 83 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 84 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 85 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 86 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 87 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 88 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 89 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 90 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 91 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 92 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 93 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 94 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 95 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 96 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 97 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 98 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 99 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 100 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 101 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 102 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 103 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 104 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 105 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 106 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 107 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 108 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 109 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 110 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 111 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 112 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 113 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 114 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 115 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 116 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 117 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 118 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 119 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 120 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 121 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 122 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 123 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 124 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 125 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 126 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 127 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 128 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 129 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 130 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 131 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 132 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 133 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 134 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 135 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 136 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 137 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 138 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 139 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 140 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 141 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 142 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 143 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 144 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 145 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 146 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 147 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 148 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 149 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 150 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 151 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 152 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 153 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 154 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 155 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 156 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 157 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 158 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 159 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 160 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 161 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 162 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 163 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 164 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 165 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 166 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 167 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 168 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 169 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 170 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 171 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 172 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 173 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 174 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 175 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 176 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 177 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 178 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 179 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 180 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 181 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 182 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 183 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 184 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 185 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured:
/ 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2731 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2732 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2733 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2734 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2735 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2736 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2737 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2738 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2739 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2740 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2741 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2742 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2743 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2744 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2745 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2746 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2747 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2748 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2749 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2750 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2751 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2752 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2753 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2754 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2755 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2756 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2757 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2758 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2759 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2760 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2761 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2762 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2763 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2764 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2765 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2766 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2767 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2768 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2769 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2770 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2771 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2772 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2773 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2774 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2775 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2776 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2777 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2778 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2779 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2780 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2781 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2782 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2783 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2784 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2785 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2786 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2787 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2788 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2789 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2790 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2791 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2792 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2793 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2794 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2795 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2796 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2797 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2798 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2799 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2800 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2801 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2802 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2803 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2804 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2805 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2806 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2807 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2808 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2809 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2810 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2811 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2812 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2813 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2814 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2815 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2816 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2817 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2818 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2819 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2820 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2821 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2822 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2823 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2824 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2825 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2826 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2827 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2828 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2829 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2830 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2831 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2832 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2833 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2834 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2835 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2836 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2837 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2838 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2839 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2840 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2841 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2842 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2843 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2844 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2845 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2846 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2847 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2848 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2849 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2850 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2851 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2852 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2853 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2854 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2855 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2856 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2857 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2858 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2859 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2860 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2861 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2862 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2863 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2864 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2865 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2866 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2867 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2868 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2869 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2870 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2871 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2872 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2873 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2874 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2875 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2876 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2877 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2878 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2879 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2880 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2881 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2882 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2883 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2884 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2885 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2886 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2887 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2888 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2889 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2890 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2891 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2892 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2893 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2894 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2895 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2896 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2897 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2898 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2899 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2900 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2901 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2902 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2903 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2904 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2905 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2906 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2907 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2908 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2909 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2910 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2911 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2912 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2913 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2914 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2915 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2916 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2917 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2918 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2919 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2920 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2921 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2922 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2923 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2924 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2925 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2926 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2927 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2928 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2929 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2930 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2931 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2932 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2933 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2934 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2935 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2936 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2937 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2938 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2939 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2940 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2941 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2942 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2943 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2944 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2945 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2946 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2947 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2948 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2949 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2950 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2951 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2952 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2953 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2954 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2955 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2956 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2957 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2958 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2959 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2960 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2961 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2962 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2963 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2964 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2965 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2966 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2967 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2968 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2969 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2970 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2971 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2972 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2973 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2974 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2975 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2976 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2977 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2978 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2979 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2980 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2981 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2982 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2983 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2984 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2985 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2986 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2987 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2988 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2989 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2990 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2991 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2992 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2993 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2994 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2995 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2996 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2997 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2998 / 3000 || SPATIAL_MAPPING_STATE.OK
# Images captured: 2999 / 3000 || SPATIAL_MAPPING_STATE.OK

# %%
err = zed.extract_whole_spatial_map(py_mesh) # Extract the whole mesh

# %%
filter_params = sl.MeshFilterParameters()
filter_params.set(sl.MESH_FILTER.LOW)
py_mesh.filter(filter_params) # Filter the mesh (remove unnecessary vertices and faces)
py_mesh.save("mesh.obj") # Save the mesh in an obj file
# Out:
# True

# %%
# Disable tracking and mapping and close the camera
zed.disable_spatial_mapping()
zed.disable_positional_tracking()
zed.close()

# %%
mapping_state
# Out:
# <SPATIAL_MAPPING_STATE.OK: 1>
